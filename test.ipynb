# %%
from main import main
main()
# Out:
# Device:  cuda
# 28539it [00:11, 2559.69it/s]
# 0it [00:00, ?it/s]
# 2703it [00:00, 2924.04it/s]
# 100%|██████████| 2620/2620 [00:00<00:00, 6477.72it/s]
# wandb: Currently logged in as: jbajor (idl-group). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/jbajor/.netrc
# Epoch: 1/40
# Epoch 1/40: Train Loss 1.6390509036089806, Train Perplex 5.739030631668364
# Validation Levenshtein Distance: 530.9867006
# Saving model
#
# Epoch: 2/40
# Epoch 2/40: Train Loss 1.310927705112594, Train Perplex 3.711297639282295
# Validation Levenshtein Distance: 536.2965843
# Epoch: 3/40
# Train:   3%|▎         | 15/446 [00:10<04:49,  1.49it/s, loss=1.2538, lr=0.0010, perplexity=3.5038, tf_rate=1.00]
# ...
