# %%
from main import main

# %%
main()
# Out:
# Device:  cuda
# 28539it [00:11, 2516.24it/s]
# 0it [00:00, ?it/s]
# 2703it [00:01, 2078.22it/s]
# 100%|██████████| 2620/2620 [00:00<00:00, 3942.38it/s]
# wandb: Currently logged in as: jbajor (idl-group). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/jbajor/.netrc
# Epoch: 1/40
# Epoch 1/40: Train Loss 2.9057142038473347, Train Perplex 18.43233891301507
# Validation Levenshtein Distance: 114.9522270
# Saving model
#
# Epoch: 2/40
# Epoch 2/40: Train Loss 2.8835346514746645, Train Perplex 17.877602564408477
# Validation Levenshtein Distance: 114.9522270
# Saving model
#
# Epoch: 3/40
# Epoch 3/40: Train Loss 2.8827298815618425, Train Perplex 17.86320219103922
# ...
