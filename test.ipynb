# %%
from main import main

# %%
main()
# Out:
# Device:  cuda
# wandb: Currently logged in as: jbajor (idl-group). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/jbajor/.netrc
# Epoch: 1/40
# Epoch 1/40: Train Loss 3.4743543799051984, Train Perplex 32.357678830266714
# Validation Levenshtein Distance: 176.2993260
# Saving model
#
# Epoch: 2/40
# Epoch 2/40: Train Loss 3.4454048222410463, Train Perplex 31.358900275772918
# Validation Levenshtein Distance: 177.6344975
# Epoch: 3/40
# Train:  45%|████▍     | 75/167 [00:05<00:06, 13.16it/s, loss=3.4452, lr=0.0010, perplexity=31.3546, tf_rate=1.00]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...
